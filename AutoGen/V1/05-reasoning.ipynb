# %%
# %pip install -r requirements.txt

# %% [markdown]
# ### Configuring the Language Model (LLM)
#
# Here, we define the configuration for the language model we want to use. This dictionary (`gemma`) specifies:
# - **model**: The specific model to use (`gemma-2-2b-it`), along with its configuration identifier.
# - **base_url**: The URL of the local server hosting the model API.
# - **api_key**: The API key needed for authentication with the model server.
# - **price**: An optional field to specify the cost per 1,000 tokens (for both input and output tokens).
# - **cache_seed**: Set to `None` to disable caching, ensuring that each request is processed freshly without using previous results.

# %%
gemma = {
    "config_list": [
        {
            "model": "lmstudio-community/gemma-2-2b-it-GGUF/gemma-2-2b-it-Q4_K_M.gguf:0",
            "base_url": "http://localhost:1234/v1",
            "api_key": "lm-studio",
            "price": [0.001, 0.001],  # Add custom pricing here (per 1k prompt/completion tokens)
        },
    ],
    "cache_seed": None,  # Disable caching.
}
verbose = False

# %%
from autogen import AssistantAgent, UserProxyAgent
from autogen.agentchat.contrib.reasoning_agent import ReasoningAgent, ThinkNode, visualize_tree

reason_agent = ReasoningAgent(
    name="reason_agent",
    system_message="answer math questions",
    llm_config=gemma,
    verbose=verbose,
    beam_size=1,  # using beam size 1 for special case of O1-style reasoning.
    max_depth=3,
)
user_proxy = UserProxyAgent(
    name="user_proxy",
    human_input_mode="NEVER",
    code_execution_config=False,
    max_consecutive_auto_reply=10,
)

# %%
question = "Alice has 3 brothers and she also has 2 sisters. How many sister does Alices brother has?"

def last_meaningful_msg(sender, recipient, summary_args):
    import warnings

    if sender == recipient:
        return "TERMINATE"

    summary = ""
    chat_messages = recipient.chat_messages[sender]

    for msg in reversed(chat_messages):
        try:
            content = msg["content"]
            if isinstance(content, str):
                summary = content.replace("TERMINATE", "")
            elif isinstance(content, list):
                # Remove the `TERMINATE` word in the content list.
                summary = "\n".join(
                    x["text"].replace("TERMINATE", "") for x in content if isinstance(x, dict) and "text" in x
                )
            if summary.strip().rstrip():
                return summary
        except (IndexError, AttributeError) as e:
            warnings.warn(f"Cannot extract summary using last_msg: {e}. Using an empty str as summary.", UserWarning)
    return summary

# %% [markdown]
# ![](https://ag2ai.github.io/ag2/assets/images/reasoningagent_2-f550949b23619bca73bd10e0cc24e3dc.png)

# %%
ans = user_proxy.initiate_chat(reason_agent, message=question, summary_method=last_meaningful_msg)
# Out:
# user_proxy (to reason_agent):
#
# Alice has 3 brothers and she also has 2 sisters. How many sister does Alices brother has?
#
# --------------------------------------------------------------------------------
# reason_agent (to tot_thinker):
#
# # Question: Alice has 3 brothers and she also has 2 sisters. How many sister does Alices brother has?
# ---
# What are the possible next steps?
#
# --------------------------------------------------------------------------------
# tot_thinker (to reason_agent):
#
# **Reflection**
# *The question is a bit of a trick, relying on wordplay to confuse the listener.  It seems like it's trying to mislead by focusing on siblings rather than defining if Alice and her brothers are inclusive of Alice herself. *
#
# **Possible Options:**
# Option 1: Clarify whether the focus is on Alice and her siblings or all of their combined total, thereby providing context for the question.
# Option 2:  Ask Alice a clarifying question to understand if she's referring to only her own set of siblings or her brothers and sisters combined.
# Option 3: Offer the solution by recognizing that the question is attempting to be confusing rather than provide any accurate information.
# Option 4: TERMINATE
#
#
#
#
# --------------------------------------------------------------------------------
# reason_agent (to tot_grader):
#
# Rate the trajectory:
# # Question: Alice has 3 brothers and she also has 2 sisters. How many sister does Alices brother has?
# Step 1: Clarify whether the focus is on Alice and her siblings or all of their combined total, thereby providing context for the question.
#
# --------------------------------------------------------------------------------
# tot_grader (to reason_agent):
#
# The thinking trajectory you've described is a **5/5 (excellent)**!
#
# Here's why:
#
# * **Recognizing Ambiguity:**  The question starts out ambiguous. It seems like it might be asking about Alice's own siblings, but then introduces additional information that could lead to conflating the total number of sisters for all the family members.
# * **Prioritizing Clarity:** Before attempting any calculations, the step focuses on clarifying the question's focus by establishing a clear understanding.
# * **Providing Context:** This approach ensures the answer isn't misinterpreted or misdirected because Alice has 3 brothers and 2 sisters, and we are trying to understand the total number of sisters among all siblings.
#
#
# This is a strong example of effective thinking: It anticipates potential confusion and takes steps to address it before proceeding with the problem-solving process.
#
#
# --------------------------------------------------------------------------------
# reason_agent (to tot_grader):
#
# Rate the trajectory:
# # Question: Alice has 3 brothers and she also has 2 sisters. How many sister does Alices brother has?
# Step 1: Ask Alice a clarifying question to understand if she's referring to only her own set of siblings or her brothers and sisters combined.
#
# --------------------------------------------------------------------------------
# tot_grader (to reason_agent):
#
# This trajectory is solid, earning a **4/5**. Here's why:
#
# **Strengths:**
#
# * **Targeting the Root of Ambiguity:**  The step correctly identifies that the question is ambiguous without clear context about whether it refers to Alice's own siblings or all siblings combined.
# * **Seeking Clarification:** A direct question like this is a great way to directly address the ambiguity, guiding Alice toward providing the necessary information for solving the problem.
#
# **Areas for Improvement:**
#
# * **Specificity of Question:** While the question is on point, it could be even more effective by:
#     *  Asking "Are you asking about how many sisters *Alice* has?"
#     *  Or "Do you mean how many sisters all the siblings in the family have combined?"
#
#
# **Overall:** This trajectory demonstrates good problem-solving and understanding of ambiguity, but could benefit from a slightly more direct and specific question.
#
# Let me know if you'd like to explore other thinking trajectories! 😊
#
#
# --------------------------------------------------------------------------------
# reason_agent (to tot_grader):
#
# Rate the trajectory:
# # Question: Alice has 3 brothers and she also has 2 sisters. How many sister does Alices brother has?
# Step 1: Offer the solution by recognizing that the question is attempting to be confusing rather than provide any accurate information.
#
# --------------------------------------------------------------------------------
# tot_grader (to reason_agent):
#
# This trajectory gets a **3/5** rating. Here's why:
#
# * **Good Observation:** The step identifies an aspect of the question that is designed to be misleading -  the "How many sister does Alices brother has?" phrasing is clearly intended to confuse or mislead.
#
#
# * **Not Addressing the Core Issue:**  The focus on the question being confusing and offering a solution might lead to missing key problem-solving opportunities. To truly rate this trajectory as great, it needs to shift its approach from just acknowledging confusion to directly addressing how Alice's siblings are related and potentially resolving the ambiguity of the question.
#
#
# **Potential Improvements:**
#
# * **Directly Addressing Ambiguity:** The step could be more effective by clarifying *why* the question is confusing.  For example:
#     * "This question uses language that tries to mislead us. It doesn't actually ask about how many sisters Alice's brothers have, but rather about a misunderstanding of her own family relationships."
#
# * **Exploring Possible Answers:** This step could be more valuable if it explored the potential ways to answer the question and how to avoid falling into the trap of ambiguity.
#
#
# **Remember:** The goal is not just to point out the trickery, but to actively help solve the problem in a clear manner by:
# 1. **Understanding the Ambiguity:**  Identifying the real meaning of the question's intent.
# 2. **Addressing the Ambiguity:** Providing solutions that are accurate and relevant.
#
#
#
#
#
#
# --------------------------------------------------------------------------------
# reason_agent (to tot_grader):
#
# Rate the trajectory:
# # Question: Alice has 3 brothers and she also has 2 sisters. How many sister does Alices brother has?
# Step 1: TERMINATE
#
# --------------------------------------------------------------------------------
# tot_grader (to reason_agent):
#
# This trajectory earns a **0/5** rating.
#
# Terminating the problem-solving process prematurely is *extremely* poor practice. Here's why:
#
# * **No Attempt at Solution:** The step takes no steps to attempt a solution or explore strategies for resolving the ambiguity.
# * **Lack of Reasoning:** There is no explanation for why the question should be terminated, making it seem like an arbitrary decision rather than a considered one.
#
#
# The goal of problem-solving is not just about identifying a trick. It's about applying logic and reasoning to solve the challenge in hand:
#
#
# **To improve this trajectory**:
# * **Attempt Solutions:**  Explore ways to break down the question and understand its inherent ambiguity, even if it seems obvious or simple at first.
# * **Clearly Articulate Reasoning:**  Explain *why* the problem should be terminated (it shouldn't!) by providing a logical and reasoned explanation for why the question is not solvable as presented.
#
#
#
# **Think of it this way:** A good trajectory is like a road map – it guides you towards a solution, even if you encounter obstacles. Terminating prematurely leads to getting lost in a maze.
#
#
# --------------------------------------------------------------------------------
# reason_agent (to tot_thinker):
#
# # Question: Alice has 3 brothers and she also has 2 sisters. How many sister does Alices brother has?
# Step 1: Clarify whether the focus is on Alice and her siblings or all of their combined total, thereby providing context for the question.
# ---
# What are the possible next steps?
#
# --------------------------------------------------------------------------------
# tot_thinker (to reason_agent):
#
# **Reflection**
# *The previous step correctly identifies that the focus needs to be clarified. This allows for a direct response to the actual question.*
#
# **Possible Options:**
# Option 1: Alice has 3 brothers and 2 sisters. Her siblings are her brothers and sisters combined, so each brother would have 2 sisters.
# Option 2: The question asks how many sisters Alice's brothers have. Alices Brothers have two sisters.
# Option 3: Since Alice shares the same sibling group with her brothers and sisters, they all share a family structure of two parents, so each sibling has a parent.
# Option 4: TERMINATE
#
#
#
#
#
# --------------------------------------------------------------------------------
# reason_agent (to tot_grader):
#
# Rate the trajectory:
# # Question: Alice has 3 brothers and she also has 2 sisters. How many sister does Alices brother has?
# Step 1: Clarify whether the focus is on Alice and her siblings or all of their combined total, thereby providing context for the question.
# Step 2: Alice has 3 brothers and 2 sisters. Her siblings are her brothers and sisters combined, so each brother would have 2 sisters.
#
# --------------------------------------------------------------------------------
# tot_grader (to reason_agent):
#
# This trajectory receives a **4/5**. Here's why:
#
# **Strengths:**
#
# * **Understanding Ambiguity:** The step correctly identifies the ambiguity of the question by clarifying whether it is asking about Alice specifically or all siblings in total.  It also recognizes that the question's phrasing is intended to confuse.
# * **Direct Solution:**  The solution clearly states the answer, based on the understanding of the family structure.
#
#
# **Areas for Improvement:**
#
# * **Avoid Circular Reasoning:** While the final step correctly states that Alice has brothers and sisters combined, it does so by implying that each brother would have two sisters – this is circular logic as we are already stating there are two sisters in the beginning. Instead, you could rephrase to clarify the relationships: "Each brother will have 2 sisters" or "Since Alice has three brothers and two sisters, her brothers share the same sister."
# * **Further Context:** While the answer is correct, providing a more robust explanation for why this solution is accurate would add value.
#
#
#
# **Overall**:  This trajectory demonstrates good problem-solving and a solid understanding of the situation, but it could be improved by refining the explanation and avoiding circular reasoning.
#
#
# Let me know if you'd like to explore other thinking trajectories! 😊
#
#
# --------------------------------------------------------------------------------
# reason_agent (to tot_grader):
#
# Rate the trajectory:
# # Question: Alice has 3 brothers and she also has 2 sisters. How many sister does Alices brother has?
# Step 1: Clarify whether the focus is on Alice and her siblings or all of their combined total, thereby providing context for the question.
# Step 2: The question asks how many sisters Alice's brothers have. Alices Brothers have two sisters.
#
# --------------------------------------------------------------------------------
# tot_grader (to reason_agent):
#
# This trajectory gets a **4/5**. Here's why:
#
# **Strengths:**
#
# * **Recognizing Ambiguity:**  The step correctly identifies that the question is designed to be confusing and needs to be clarified.
# * **Direct Solution:** The solution directly addresses the question and provides a clear answer.
#
#
# **Areas for Improvement:**
#
# * **Redundancy:** The steps are somewhat redundant, as the conclusion is derived from the initial identification of the ambiguity.  A single step could accomplish both.
# * **Specificity:**  The phrase "Alices brother has two sisters" can be more precise to avoid potential confusion.
#
# **Here's an alternative, slightly more concise trajectory that would still achieve a strong result:**
#
# * **Step 1: Clarify:** Identify the ambiguity of the question and ensure everyone understands if it refers to Alice herself or all family members combined
# * **Step 2: Correcting the Misdirection:**  Explain why the question is misleading by pointing out the inherent contradiction in asking about Alice's brothers' sisters.
#
#
#
# **Overall:** The trajectory demonstrates a solid understanding of the problem's ambiguity and provides a clear solution, but could benefit from a bit more efficiency and precision.
#
# Let me know if you'd like to explore other trajectories! 😊
#
#
# --------------------------------------------------------------------------------
# reason_agent (to tot_grader):
#
# Rate the trajectory:
# # Question: Alice has 3 brothers and she also has 2 sisters. How many sister does Alices brother has?
# Step 1: Clarify whether the focus is on Alice and her siblings or all of their combined total, thereby providing context for the question.
# Step 2: Since Alice shares the same sibling group with her brothers and sisters, they all share a family structure of two parents, so each sibling has a parent.
#
# --------------------------------------------------------------------------------
# tot_grader (to reason_agent):
#
# This trajectory gets a **3/5**.
#
# Here's why:
#
# **Strengths:**
#
# * **Identifying Ambiguity:**  The step correctly points out the question is designed to be confusing and requires clarification.
# * **Understanding Family Relationships:** It attempts to link family dynamics (siblings) to clarify the answer by suggesting siblings share a parent, which helps in determining how many sisters each brother has.
#
#
# **Areas for Improvement:**
#
# * **Lack of Direct Solution:**  While the reasoning is good, it doesn't directly address the core of the question. The step could be more direct:
#     * Instead of "since Alice shares the same sibling group...," go straight to the solution:  "Alice has 3 brothers and 2 sisters. Her brother each shares two sisters with her."
#
#
# **Additional Thoughts:**
#
# * **Avoiding Circular Reasoning:** While the explanation about siblings sharing a family structure is helpful, it doesn't directly solve the question's core issue of how many sisters Alice's brothers have.
#
#
#
# This trajectory demonstrates an understanding of the problem's ambiguity and attempts to provide reasoning for its solution, but could benefit from being more direct and avoiding circular logic.
#
#
#
#
# --------------------------------------------------------------------------------
# reason_agent (to tot_grader):
#
# Rate the trajectory:
# # Question: Alice has 3 brothers and she also has 2 sisters. How many sister does Alices brother has?
# Step 1: Clarify whether the focus is on Alice and her siblings or all of their combined total, thereby providing context for the question.
# Step 2: TERMINATE
#
# --------------------------------------------------------------------------------
# tot_grader (to reason_agent):
#
# This trajectory gets a **0/5**.
#
# **Why:**
#
# * **No Solution:** The step identifies an ambiguity in the question but then immediately terminates the problem-solving process. This is incorrect.
#
# A good solution to this type of puzzle would involve using logic and reasoning to identify that Alice's brothers all share the same two sisters, giving a clear answer of "two".
#
#
# **The Importance of Solving the Problem:**
# * **Understanding Ambiguity:**  Identifying the ambiguity in the question is important but not enough.
# * **Solving the Problem:** A solution should be derived from the initial steps to provide an accurate result rather than simply terminating the process.
#
#
#
# Let me know if you'd like to explore other thinking trajectories! 😊
#
# --------------------------------------------------------------------------------
# reason_agent (to tot_thinker):
#
# # Question: Alice has 3 brothers and she also has 2 sisters. How many sister does Alices brother has?
# Step 1: Clarify whether the focus is on Alice and her siblings or all of their combined total, thereby providing context for the question.
# Step 2: Alice has 3 brothers and 2 sisters. Her siblings are her brothers and sisters combined, so each brother would have 2 sisters.
# ---
# What are the possible next steps?
#
# --------------------------------------------------------------------------------
# tot_thinker (to reason_agent):
#
# **Reflection**
# The previous steps correctly established that Alice has 2 sisters but seem to misinterpret the question.  The focus should be on individual siblings, not their combined total.
#
# **Possible Options:**
# Option 1:  Reiterate the focus is on Alice's brothers and sisters individually, not their combined totals.
# Option 2: Analyze if it is possible to interpret Alice's statement "how many sisters does her brother have" as referring to a sibling group of all siblings.
# Option 3: Correct the previous step by stating that each brother has 2 sisters and only Alice's brothers would have a sister, not Alice's sisters.
# Option 4: TERMINATE
#
#
#
#
#
# --------------------------------------------------------------------------------
# reason_agent (to tot_grader):
#
# Rate the trajectory:
# # Question: Alice has 3 brothers and she also has 2 sisters. How many sister does Alices brother has?
# Step 1: Clarify whether the focus is on Alice and her siblings or all of their combined total, thereby providing context for the question.
# Step 2: Alice has 3 brothers and 2 sisters. Her siblings are her brothers and sisters combined, so each brother would have 2 sisters.
# Step 3: Reiterate the focus is on Alice's brothers and sisters individually, not their combined totals.
#
# --------------------------------------------------------------------------------
# tot_grader (to reason_agent):
#
# This trajectory gets a **4/5**.
#
# Here's why:
#
# **Strengths:**
#
# * **Identifying Ambiguity:** The step correctly identifies that the question is designed to be confusing and requires clarification.
# * **Understanding Family Relationships:** It attempts to link family dynamics (siblings) to clarify the answer by suggesting siblings share a parent, which helps in determining how many sisters Alice's brothers have.
# * **Reiterating Focus:** The final step correctly clarifies that the question is indeed asking about Alice's brothers and not their combined total.
#
#
# **Areas for Improvement:**
#
# *  **Redundancy (Step 2):**  The explanation in step 2 could be streamlined. A simple statement like "Alice has three brothers and two sisters." followed by "Therefore, each brother would have two sisters" is sufficient.
#
# * **More Concise Explanations:** The steps could benefit from a more concise explanation of the family structure's relationship to solve the question.
#
#
#
# **Overall:** This trajectory demonstrates a solid approach to solving this type of problem by identifying ambiguity, attempting to provide context and explaining the solution clearly but it could be made even stronger with some refinements!
#
#
# Let me know if you have any other trajectory ideas you'd like to explore! 😊
#
#
# --------------------------------------------------------------------------------
# reason_agent (to tot_grader):
#
# Rate the trajectory:
# # Question: Alice has 3 brothers and she also has 2 sisters. How many sister does Alices brother has?
# Step 1: Clarify whether the focus is on Alice and her siblings or all of their combined total, thereby providing context for the question.
# Step 2: Alice has 3 brothers and 2 sisters. Her siblings are her brothers and sisters combined, so each brother would have 2 sisters.
# Step 3: Analyze if it is possible to interpret Alice's statement "how many sisters does her brother have" as referring to a sibling group of all siblings.
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ans = user_proxy.initiate_chat(reason_agent, message=question, summary_method=last_meaningful_msg)
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1152, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1150     else:
#    1151         msg2send = self.generate_init_message(message, **kwargs)
# -> 1152     self.send(msg2send, recipient, silent=silent)
#    1153 summary = self._summarize_chat(
#    1154     summary_method,
#    1155     summary_args,
#    1156     recipient,
#    1157     cache=cache,
#    1158 )
#    1159 for agent in [self, recipient]:
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:787, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#     785 valid = self._append_oai_message(message, "assistant", recipient, is_sending=True)
#     786 if valid:
# --> 787     recipient.receive(message, self, request_reply, silent)
#     788 else:
#     789     raise ValueError(
#     790         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     791     )
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:952, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     950 if request_reply is False or request_reply is None and self.reply_at_receive[sender] is False:
#     951     return
# --> 952 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     953 if reply is not None:
#     954     self.send(reply, sender, silent=silent)
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:2109, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    2107     continue
#    2108 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 2109     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    2110     if logging_enabled():
#    2111         log_event(
#    2112             self,
#    2113             "reply_func_executed",
#    (...)
#    2117             reply=reply,
#    2118         )
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/autogen/agentchat/contrib/reasoning_agent.py:293, in ReasoningAgent.generate_response(self, messages, sender, config)
#     291 # Rate
#     292 for node in prev_leafs:
# --> 293     node.value = self.rate_node(node)
#     294 # Beam search: keep top beam_size leaf nodes
#     295 prev_leafs = sorted(prev_leafs, key=lambda x: x.value if x.value else 0, reverse=True)[
#     296     : self.beam_size - len(final_answers)
#     297 ]
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/autogen/agentchat/contrib/reasoning_agent.py:218, in ReasoningAgent.rate_node(self, node)
#     209 def rate_node(self, node: ThinkNode) -> float:
#     210     """Rate the quality of a reasoning path using the grader agent.
#     211
#     212     Args:
#    (...)
#     216         float: Normalized score between 0 and 1 indicating trajectory quality
#     217     """
# --> 218     self.send(
#     219         message=f"Rate the trajectory:\n{node.trajectory}", recipient=self.grader, request_reply=True, silent=False
#     220     )
#     221     rating = self.grader.last_message()["content"].strip()
#     222     try:
#     223         # Scale rating to [0, 1]
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:787, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#     785 valid = self._append_oai_message(message, "assistant", recipient, is_sending=True)
#     786 if valid:
# --> 787     recipient.receive(message, self, request_reply, silent)
#     788 else:
#     789     raise ValueError(
#     790         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     791     )
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:952, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     950 if request_reply is False or request_reply is None and self.reply_at_receive[sender] is False:
#     951     return
# --> 952 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     953 if reply is not None:
#     954     self.send(reply, sender, silent=silent)
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:2109, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    2107     continue
#    2108 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 2109     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    2110     if logging_enabled():
#    2111         log_event(
#    2112             self,
#    2113             "reply_func_executed",
#    (...)
#    2117             reply=reply,
#    2118         )
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1474, in ConversableAgent.generate_oai_reply(self, messages, sender, config)
#    1472 if messages is None:
#    1473     messages = self._oai_messages[sender]
# -> 1474 extracted_response = self._generate_oai_reply_from_client(
#    1475     client, self._oai_system_message + messages, self.client_cache
#    1476 )
#    1477 return (False, None) if extracted_response is None else (True, extracted_response)
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1493, in ConversableAgent._generate_oai_reply_from_client(self, llm_client, messages, cache)
#    1490         all_messages.append(message)
#    1492 # TODO: #1143 handle token limit exceeded error
# -> 1493 response = llm_client.create(
#    1494     context=messages[-1].pop("context", None),
#    1495     messages=all_messages,
#    1496     cache=cache,
#    1497     agent=self,
#    1498 )
#    1499 extracted_response = llm_client.extract_text_or_completion_object(response)[0]
#    1501 if extracted_response is None:
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/autogen/oai/client.py:869, in OpenAIWrapper.create(self, **config)
#     867 try:
#     868     request_ts = get_current_ts()
# --> 869     response = client.create(params)
#     870 except APITimeoutError as err:
#     871     logger.debug(f"config {i} timed out", exc_info=True)
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/autogen/oai/client.py:423, in OpenAIClient.create(self, params)
#     421     params = params.copy()
#     422     params["stream"] = False
# --> 423     response = create_or_parse(**params)
#     425 return response
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/openai/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/openai/resources/chat/completions.py:829, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     788 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     789 def create(
#     790     self,
#    (...)
#     826     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     827 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     828     validate_response_format(response_format)
# --> 829     return self._post(
#     830         "/chat/completions",
#     831         body=maybe_transform(
#     832             {
#     833                 "messages": messages,
#     834                 "model": model,
#     835                 "audio": audio,
#     836                 "frequency_penalty": frequency_penalty,
#     837                 "function_call": function_call,
#     838                 "functions": functions,
#     839                 "logit_bias": logit_bias,
#     840                 "logprobs": logprobs,
#     841                 "max_completion_tokens": max_completion_tokens,
#     842                 "max_tokens": max_tokens,
#     843                 "metadata": metadata,
#     844                 "modalities": modalities,
#     845                 "n": n,
#     846                 "parallel_tool_calls": parallel_tool_calls,
#     847                 "prediction": prediction,
#     848                 "presence_penalty": presence_penalty,
#     849                 "response_format": response_format,
#     850                 "seed": seed,
#     851                 "service_tier": service_tier,
#     852                 "stop": stop,
#     853                 "store": store,
#     854                 "stream": stream,
#     855                 "stream_options": stream_options,
#     856                 "temperature": temperature,
#     857                 "tool_choice": tool_choice,
#     858                 "tools": tools,
#     859                 "top_logprobs": top_logprobs,
#     860                 "top_p": top_p,
#     861                 "user": user,
#     862             },
#     863             completion_create_params.CompletionCreateParams,
#     864         ),
#     865         options=make_request_options(
#     866             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     867         ),
#     868         cast_to=ChatCompletion,
#     869         stream=stream or False,
#     870         stream_cls=Stream[ChatCompletionChunk],
#     871     )
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/openai/_base_client.py:1280, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1266 def post(
#    1267     self,
#    1268     path: str,
#    (...)
#    1275     stream_cls: type[_StreamT] | None = None,
#    1276 ) -> ResponseT | _StreamT:
#    1277     opts = FinalRequestOptions.construct(
#    1278         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1279     )
# -> 1280     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/openai/_base_client.py:957, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     954 else:
#     955     retries_taken = 0
# --> 957 return self._request(
#     958     cast_to=cast_to,
#     959     options=options,
#     960     stream=stream,
#     961     stream_cls=stream_cls,
#     962     retries_taken=retries_taken,
#     963 )
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/openai/_base_client.py:993, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     990 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     992 try:
# --> 993     response = self._client.send(
#     994         request,
#     995         stream=stream or self._should_stream_response_body(request=request),
#     996         **kwargs,
#     997     )
#     998 except httpx.TimeoutException as err:
#     999     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/GitHub/dy/codesamples/AutoGen/.venv/lib/python3.10/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
# After running a query, visualize the reasoning tree
print(ans.summary)
visualize_tree(reason_agent._root)

# %% [markdown]
# # Tree of Toughts

# %% [markdown]
# ![](tree_of_thoughts.png)

# %%
reason_agent = ReasoningAgent(
    name="reason_agent",
    llm_config=gemma,
    verbose=verbose,
    beam_size=3,
    max_depth=3,
)
user_proxy = UserProxyAgent(
    name="user_proxy",
    human_input_mode="NEVER",
    code_execution_config={"use_docker": False},
    max_consecutive_auto_reply=10,
)

# %%
ans = user_proxy.initiate_chat(
    reason_agent,
    message="Alice has 3 brothers and she also has 2 sisters. How many sister does Alices brother has?",
    summary_method=last_meaningful_msg,
)
